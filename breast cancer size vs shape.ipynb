# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#importing our breast cancer dataset
dataset = pd.read_csv('/Users/idrisa/Desktop/INST737/data 2.csv')

# %%
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dataset.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
print(dataset.shape)
# Out:
# (569, 33)

# %%
 for col in dataset.columns:
    print(col)
# Out:
# id
# diagnosis
# radius_mean
# texture_mean
# perimeter_mean
# area_mean
# smoothness_mean
# compactness_mean
# concavity_mean
# concave points_mean
# symmetry_mean
# fractal_dimension_mean
# radius_se
# texture_se
# perimeter_se
# area_se
# smoothness_se
# compactness_se
# concavity_se
# concave points_se
# symmetry_se
# fractal_dimension_se
# radius_worst
# texture_worst
# perimeter_worst
# area_worst
# smoothness_worst
# compactness_worst
# concavity_worst
# concave points_worst
# symmetry_worst
# fractal_dimension_worst
# Unnamed: 32

# %%
# find any missing data points 
dataset.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# ...

# %%
dataset.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
import matplotlib.pyplot as plt

# Count the number of samples in each class
counts = dataset['diagnosis'].value_counts()

# Create a bar graph
plt.bar(counts.index, counts.values)

# Add axis labels and title
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.title('Distribution of Diagnosis')

# Show the plot
plt.show()

# %% [markdown]
# The research question is which feature is the best predictor of malignancy? First I will separate the column headings into different categories: size (radius, perimeter, area, fractal dimension) or shape (texture, smoothness, compactness, concavity, concave points). We can plot the data differently looking at the correlations between each feature and malignancy/benigness).

# %%
size = dataset[['area_mean', 'radius_mean', 'perimeter_mean', 'fractal_dimension_mean','diagnosis']]
print(size)
# Out:
#      area_mean  radius_mean  perimeter_mean  fractal_dimension_mean diagnosis
# 0       1001.0        17.99          122.80                 0.07871         M
# 1       1326.0        20.57          132.90                 0.05667         M
# 2       1203.0        19.69          130.00                 0.05999         M
# 3        386.1        11.42           77.58                 0.09744         M
# 4       1297.0        20.29          135.10                 0.05883         M
# ..         ...          ...             ...                     ...       ...
# 564     1479.0        21.56          142.00                 0.05623         M
# 565     1261.0        20.13          131.20                 0.05533         M
# 566      858.1        16.60          108.30                 0.05648         M
# 567     1265.0        20.60          140.10                 0.07016         M
# 568      181.0         7.76           47.92                 0.05884         B
#
# [569 rows x 5 columns]

# %%
shape = dataset[['texture_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean','diagnosis']]
print(shape)
# Out:
#      texture_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0           10.38          0.11840           0.27760         0.30010
# 1           17.77          0.08474           0.07864         0.08690
# 2           21.25          0.10960           0.15990         0.19740
# 3           20.38          0.14250           0.28390         0.24140
# 4           14.34          0.10030           0.13280         0.19800
# ..            ...              ...               ...             ...
# 564         22.39          0.11100           0.11590         0.24390
# 565         28.25          0.09780           0.10340         0.14400
# 566         28.08          0.08455           0.10230         0.09251
# 567         29.33          0.11780           0.27700         0.35140
# 568         24.54          0.05263           0.04362         0.00000
#
#      concave points_mean  symmetry_mean diagnosis
# 0                0.14710         0.2419         M
# ...

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X1_train, X1_test, y_train, y_test = train_test_split(dataset.area_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)
# Train a logistic regression model
model1 = LogisticRegression()
model1.fit(X1_train, y_train)

# Predict the classes of the testing data
y_pred = model1.predict(X1_test)

# Evaluate the accuracy of the model
accuracy = model1.score(X1_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9210526315789473

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X2_train, X2_test, y_train, y_test = train_test_split(dataset.radius_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model2 = LogisticRegression()
model2.fit(X2_train, y_train)

# Predict the classes of the testing data
y_pred = model2.predict(X2_test)

# Evaluate the accuracy of the model
accuracy = model2.score(X2_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9122807017543859

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X3_train, X3_test, y_train, y_test = train_test_split(dataset.perimeter_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model3 = LogisticRegression()
model3.fit(X3_train, y_train)

# Predict the classes of the testing data
y_pred = model3.predict(X3_test)

# Evaluate the accuracy of the model
accuracy = model3.score(X3_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9298245614035088

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X4_train, X4_test, y_train, y_test = train_test_split(dataset.fractal_dimension_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model4 = LogisticRegression()
model4.fit(X4_train, y_train)

# Predict the classes of the testing data
y_pred = model4.predict(X4_test)

# Evaluate the accuracy of the model
accuracy = model4.score(X4_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6228070175438597

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X5_train, X5_test, y_train, y_test = train_test_split(dataset.smoothness_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model5 = LogisticRegression()
model5.fit(X5_train, y_train)

# Predict the classes of the testing data
y_pred = model5.predict(X5_test)

# Evaluate the accuracy of the model
accuracy = model5.score(X5_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6228070175438597

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X6_train, X6_test, y_train, y_test = train_test_split(dataset.texture_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model6 = LogisticRegression()
model6.fit(X6_train, y_train)

# Predict the classes of the testing data
y_pred = model6.predict(X6_test)

# Evaluate the accuracy of the model
accuracy = model6.score(X6_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6929824561403509

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X7_train, X7_test, y_train, y_test = train_test_split(dataset.compactness_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model7 = LogisticRegression()
model7.fit(X7_train, y_train)

# Predict the classes of the testing data
y_pred = model7.predict(X7_test)

# Evaluate the accuracy of the model
accuracy = model7.score(X7_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6842105263157895

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X8_train, X8_test, y_train, y_test = train_test_split(dataset.concavity_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model8 = LogisticRegression()
model8.fit(X8_train, y_train)

# Predict the classes of the testing data
y_pred = model8.predict(X8_test)

# Evaluate the accuracy of the model
accuracy = model8.score(X8_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7982456140350878

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Create a binary variable for malignant tumors
dataset['malignant'] = np.where(dataset['diagnosis'] == 'M', 1, 0)

X9_train, X9_test, y_train, y_test = train_test_split(dataset.symmetry_mean.values.reshape(-1, 1), 
                                                    dataset.diagnosis, 
                                                    test_size=0.2, 
                                                    random_state=42)

# Train a logistic regression model
model9 = LogisticRegression()
model9.fit(X9_train, y_train)

# Predict the classes of the testing data
y_pred = model9.predict(X9_test)

# Evaluate the accuracy of the model
accuracy = model9.score(X9_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6228070175438597

# %%
Y_pred1 = model1.predict(X1_test)
print("Predicted classes:", Y_pred1)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
Y_pred2 = model2.predict(X2_test)
print("Predicted classes:", Y_pred2)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'B'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
Y_pred3 = model3.predict(X3_test)
print("Predicted classes:", Y_pred3)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
Y_pred4 = model4.predict(X4_test)
print("Predicted classes:", Y_pred4)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
Y_pred5 = model5.predict(X5_test)
print("Predicted classes:", Y_pred5)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
Y_pred6 = model6.predict(X6_test)
print("Predicted classes:", Y_pred6)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'M' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B'
#  'B' 'B' 'B' 'B' 'M' 'M']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
Y_pred7 = model7.predict(X7_test)
print("Predicted classes:", Y_pred7)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
Y_pred8 = model.predict(X5_test)
print("Predicted classes:", Y_pred5)
print("True classes:", y_test.values)
# Out:
# Predicted classes: ['B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'B']
# True classes: ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(10, 3, figsize=(15, 40))
axs = axs.flatten()

for i, feature in enumerate(dataset.columns[2:]):
    for diagnosis in ['M', 'B']:
        axs[i].hist(dataset[dataset.diagnosis==diagnosis][feature], alpha=0.5, label=diagnosis)
    axs[i].legend(loc='upper right')
    axs[i].set_title(feature)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[131], line 8
#       6 for i, feature in enumerate(dataset.columns[2:]):
#       7     for diagnosis in ['M', 'B']:
# ----> 8         axs[i].hist(dataset[dataset.diagnosis==diagnosis][feature], alpha=0.5, label=diagnosis)
#       9     axs[i].legend(loc='upper right')
#      10     axs[i].set_title(feature)
#
# IndexError: index 30 is out of bounds for axis 0 with size 30

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Concatenate radius_mean and area_mean into a single feature vector
X1 = np.column_stack((dataset.radius_mean, dataset.area_mean, dataset.perimeter_mean, dataset.fractal_dimension_mean))

# Split the data into training and testing sets
X1_train, X1_test, y_train, y_test = train_test_split(X1, dataset.diagnosis, test_size=0.2, random_state=42)

# Train a logistic regression model
model = LogisticRegression()
model.fit(X1_train, y_train)

# Predict the classes of the testing data
y_pred = model.predict(X1_test)

# Evaluate the accuracy of the model
accuracy = model.score(X1_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9385964912280702

# %%
# Predict the classes of the testing data
y_pred = model.predict(X1_test)

# Print the predicted class labels (M/B)
print(y_pred)
# Out:
# ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M']

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_test_binary = le.fit_transform(y_test)

# Convert y_pred from string to numerical values
y_pred_encoded = le.transform(y_pred)

# Calculate the false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test_binary, y_pred_encoded)

# Calculate the area under the curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # plot the diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Concatenate radius_mean and area_mean into a single feature vector
X2 = np.column_stack((dataset.texture_mean, dataset.smoothness_mean, dataset.compactness_mean, 
                     dataset.concavity_mean, 
                     dataset.symmetry_mean))
                     
# Split the data into training and testing sets
X2_train, X2_test, y_train, y_test = train_test_split(X2, dataset.diagnosis, test_size=0.2, random_state=42)

# Train a logistic regression model
model = LogisticRegression()
model.fit(X2_train, y_train)

# Predict the classes of the testing data
y_pred = model.predict(X2_test)

# Evaluate the accuracy of the model
accuracy = model.score(X2_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7894736842105263

# %%
# Predict the classes of the testing data
y_pred = model.predict(X2_test)

# Print the predicted class labels (M/B)
print(y_pred)
# Out:
# ['B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'M' 'M']

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_test_binary = le.fit_transform(y_test)

# Convert y_pred from string to numerical values
y_pred_encoded = le.transform(y_pred)

# Calculate the false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test_binary, y_pred_encoded)

# Calculate the area under the curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # plot the diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# From this analysis, we see that size is a better predictor of malignancy vs shape
